# %%
# %load_ext autoreload
# %autoreload 2

# %%
from majordome.su2 import (
    YesNoEnum,
    SolverType,
    InletType,
    ConvectiveScheme,
    LinearSolver,
    Preconditioner,
    MathProblem,
    NumMethodGrad,
    MgCycle,
    TimeDiscretization
)
from majordome.su2 import (
    ProblemDefinition,
    CompressibleFreeStreamDefinition,
    ReferenceValues,
    BoundaryConditions,
    SurfacesIdentification,
    SU2Configuration,
)

# %%
inlet_type          = InletType.TOTAL_CONDITIONS
convective_scheme   = ConvectiveScheme.JST
linear_solver       = LinearSolver.FGMRES
preconditioner      = Preconditioner.ILU
math_problem        = MathProblem.NONE
num_method_grad     = NumMethodGrad.GREEN_GAUSS
mg_cycle            = MgCycle.W_CYCLE
time_discretization = TimeDiscretization.EULER_IMPLICIT

# inlet_type.validate_solver(SolverType.EULER)

# %%
conf = SU2Configuration(
    problem = ProblemDefinition(
        solver = SolverType.EULER,
    )
)

conf.compressible_freestream = CompressibleFreeStreamDefinition(
    mach             = 0.5,
    angle_of_attack  = 0.0,
    sideslip_angle   = 0.0,
    pressure         = 101325.0,
    temperature      = 288.0
)

conf.reference_values = ReferenceValues(
    ref_origin_moment_x = 0.25,
    ref_origin_moment_y = 0.00,
    ref_origin_moment_z = 0.00,
    ref_length          = 1.0,
    ref_area            = 1.0
)

conf.boundary_conditions = BoundaryConditions(
    marker_euler  = ["upper_wall", "lower_wall"],
    marker_inlet  = ["inlet", 288.6, 102010.0, 1.0, 0.0, 0.0],
    marker_outlet = ["outlet", 101300.0],
    inlet_type    = InletType.TOTAL_CONDITIONS,
)

conf.surfaces_identification = SurfacesIdentification(
    marker_plotting   = ["lower_wall"],
    marker_monitoring = ["upper_wall", "lower_wall"],
)

print(conf.to_cfg())
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %% DIRECT, ADJOINT, AND LINEARIZED PROBLEM DEFINITION
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# SOLVER= EULER
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %% COMPRESSIBLE FREE-STREAM CONDITIONS DEFINITION
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# MACH_NUMBER= 0.5
#
# AOA= 0.0
#
# SIDESLIP_ANGLE= 0.0
#
# FREESTREAM_PRESSURE= 101325.0
#
# FREESTREAM_TEMPERATURE= 288.0
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %% REFERENCE VALUES DEFINITION
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# REF_ORIGIN_MOMENT_X= 0.25
#
# REF_ORIGIN_MOMENT_Y= 0.0
#
# REF_ORIGIN_MOMENT_Z= 0.0
#
# REF_LENGTH= 1.0
#
# REF_AREA= 1.0
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %% BOUNDARY CONDITION DEFINITION
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# MARKER_EULER= ( upper_wall, lower_wall )
#
# INLET_TYPE= TOTAL_CONDITIONS
#
# MARKER_INLET= ( inlet, 288.6, 102010.0, 1.0, 0.0, 0.0 )
#
# MARKER_OUTLET= ( outlet, 101300.0 )
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %% SURFACES IDENTIFICATION
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# MARKER_PLOTTING= ( lower_wall )
#
# MARKER_MONITORING= ( upper_wall, lower_wall )
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %% EOF
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

# %%
conf
# Out:
# SU2Configuration(problem=ProblemDefinition(solver=<SolverType.EULER: 'EULER'>, turbulence_model=<TurbulenceModel.NONE: 'NONE'>, sst_options=<ShearStressTransportModel.NONE: 'NONE'>, sa_options=<SpalartAllmarasModel.NONE: 'NONE'>, transition_model=<TransitionModel.NONE: 'NONE'>, hroughness=1e-06, lm_options=<LmTransitionModelOptions.NONE: 'NONE'>, sgs_model=<SgsModel.NONE: 'NONE'>, solution_verification=<Verification.NONE: 'NO_VERIFICATION_SOLUTION'>, math_problem=<MathProblem.NONE: 'NONE'>, axisymmetric=<YesNoEnum.NONE: 'NONE'>, gravity_force=<YesNoEnum.NONE: 'NONE'>, restart_sol=<YesNoEnum.NONE: 'NONE'>, wrt_restart_compact=<YesNoEnum.NONE: 'NONE'>, discard_infiles=<YesNoEnum.NONE: 'NONE'>, system_measurements=<UnitSystem.NONE: 'NONE'>, config_list=[]), compressible_freestream=CompressibleFreeStreamDefinition(mach=0.5, angle_of_attack=0.0, sideslip_angle=0.0, init_option=<FSInitOption.NONE: 'NONE'>, freestream_option=<FSOption.NONE: 'NONE'>, pressure=101325.0, temperature=288.0, temperature_ve=None, reynolds_number=None, reynolds_length=None, density=None, velocity=None, viscosity=None, turbulence_intensity=None, intermittency=None, turb_fixed_values=<YesNoEnum.NO: 'NO'>, turb_fixed_values_domain=None, freestream_turb2lamviscratio=None, ref_dimensionalization=<FSRefDimensionalization.NONE: 'NONE'>), reference_values=ReferenceValues(ref_origin_moment_x=0.25, ref_origin_moment_y=0.0, ref_origin_moment_z=0.0, ref_length=1.0, ref_velocity=None, ref_viscosity=None, ref_area=1.0, semi_span=None), boundary_conditions=BoundaryConditions(marker_euler=['upper_wall', 'lower_wall'], marker_heatflux=['NONE'], marker_heattransfer=['NONE'], marker_isothermal=['NONE'], marker_far=['NONE'], marker_sym=['NONE'], marker_internal=['NONE'], marker_nearfield=['NONE'], marker_periodic=['NONE'], marker_inlet=['inlet', 288.6, 102010.0, 1.0, 0.0, 0.0], marker_outlet=['outlet', 101300.0], marker_inlet_turbulent=['NONE'], marker_supersonic_inlet=['NONE'], marker_supersonic_outlet=['NONE'], marker_actdisk=['NONE'], marker_actdisk_bem_cg=['NONE'], marker_actdisk_bem_axis=['NONE'], marker_engine_inflow=['NONE'], marker_engine_exhaust=['NONE'], marker_normal_displ=['NONE'], marker_pressure=['NONE'], marker_riemann=['NONE'], marker_shroud=['NONE'], marker_zone_interface=['NONE'], marker_cht_interface=['NONE'], marker_fluid_interface=['NONE'], marker_fluid_load=['NONE'], marker_smoluchowski_maxwell=['NONE'], marker_clamped=['NONE'], marker_damper=['NONE'], marker_load=['NONE'], marker_turbomachinery=['NONE'], marker_mixingplane_interface=['NONE'], marker_giles=['NONE'], catalytic_wall=['NONE'], marker_displacement=['NONE'], marker_custom=['NONE'], inlet_type=<InletType.TOTAL_CONDITIONS: 'TOTAL_CONDITIONS'>, specified_inlet_profile=<YesNoEnum.NONE: 'NONE'>, inlet_filename=None, inlet_matching_tolerance=None, inlet_interpolation_function=<InletInterpolationFunction.NONE: 'NONE'>, inlet_interpolation_data_type=<InletInterpolationDataType.VR_VTHETA: 'VR_VTHETA'>, print_inlet_interpolated_data=<YesNoEnum.NONE: 'NONE'>, actdisk_double_surface=<YesNoEnum.NONE: 'NONE'>, actdisk_type=<ActuatorDiskType.VARIABLES_JUMP: 'VARIABLES_JUMP'>, actdisk_filename=None, bem_prop_filename=None, bem_prop_blade_angle=None, bem_freq=None, engine_inflow_type=<EngineInflowType.FAN_FACE_MACH: 'FAN_FACE_MACH'>, kind_interpolation=<KindInterpolation.NEAREST_NEIGHBOR: 'NEAREST_NEIGHBOR'>, conservative_interpolation=<YesNoEnum.NONE: 'NONE'>, kind_radial_basis_function=<KindRadialBasisFunction.WENDLAND_C2: 'WENDLAND_C2'>, radial_basis_function_parameter=None, radial_basis_function_polynomial_term=<YesNoEnum.NONE: 'NONE'>, radial_basis_function_prune_tolerance=None, num_spanwise_sections=None, spanwise_kind=None, giles_extra_relaxfactor=None, spatial_fourier=<YesNoEnum.NONE: 'NONE'>, supercatalytic_wall=<YesNoEnum.NONE: 'NONE'>, supercatalytic_wall_composition=None, catalytic_efficiency=None, sine_load=<YesNoEnum.NONE: 'NONE'>, sine_load_coeff=None, ramp_and_release_load=<YesNoEnum.NONE: 'NON ...
